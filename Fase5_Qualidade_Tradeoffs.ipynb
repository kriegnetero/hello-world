// %% [markdown]
// # 📊 Fase 5 — Avaliação de Qualidade e Trade-offs Arquiteturais
// ## Métricas, Refactoring e Decision Model
//
// ---
// **Roteiro-Desafio-ES · Fatec SCS · ADS 4º Semestre · 2026**
// **Grupo:** Isaac Gomes  **Data:** 18/05/2026
//
// ---
//
// ### 🎯 Objetivo desta fase
// Avaliar a qualidade do agente implementado na Fase 4 usando métricas de engenharia de software, aplicar o **Decision Model** do artigo CSIRO e propor refatorações com base em trade-offs arquiteturais.
//
// ### 📚 O que você vai aprender
// - Atributos de qualidade ISO 25010 aplicados a sistemas de agentes
// - Métricas de acoplamento, coesão e complexidade
// - O Decision Model do artigo CSIRO para seleção de padrões
// - Refactoring guiado por padrões
//
// ---

// %% [markdown]
// ## 🔹 Passo 1 — Atributos de Qualidade ISO 25010

// %%
// ══ ISO 25010 — Atributos de Qualidade de Software ══
System.out.println("╔══════════════════════════════════════════════════════╗");
System.out.println("║        ISO 25010 — MODELO DE QUALIDADE              ║");
System.out.println("╠═══════════════════╦══════════════════════════════════╣");
System.out.println("║ Atributo          ║ Relevância para Agentes IA      ║");
System.out.println("╠═══════════════════╬══════════════════════════════════╣");
System.out.println("║ Funcionalidade    ║ O agente cumpre os objetivos?   ║");
System.out.println("║ Confiabilidade    ║ Lida com alucinações e erros?   ║");
System.out.println("║ Usabilidade       ║ Interface clara para o usuário? ║");
System.out.println("║ Eficiência        ║ Latência e custo de API?        ║");
System.out.println("║ Manutenibilidade  ║ Fácil de evoluir e corrigir?    ║");
System.out.println("║ Portabilidade     ║ Troca de LLM sem refatoração?   ║");
System.out.println("║ Segurança         ║ Guardrails contra conteúdo      ║");
System.out.println("║                   ║ prejudicial?                    ║");
System.out.println("║ Compatibilidade   ║ Integra com ferramentas         ║");
System.out.println("║                   ║ externas via adapters?          ║");
System.out.println("╚═══════════════════╩══════════════════════════════════╝");

// %% [markdown]
// ## 🔹 Passo 2 — Analisando Métricas do Agente

// %%
// ══ MÉTRICAS DE QUALIDADE DO CÓDIGO DA FASE 4 ══

System.out.println("📊 ANÁLISE DE MÉTRICAS — Agente da Fase 4\n");

// Acoplamento Aferente (Ca) — quem depende desta classe?
// Acoplamento Eferente (Ce) — de quem esta classe depende?
System.out.println("═══════ ACOPLAMENTO ═══════");
System.out.println("Classe                 Ca  Ce  Instabilidade (Ce/(Ca+Ce))");
System.out.println("─────────────────────────────────────────────────────────");
System.out.println("Goal (Entity)           3   0   0.00 (estável)");
System.out.println("Plan (Entity)           2   1   0.33 (estável)");
System.out.println("LLMGateway (Port)       2   0   0.00 (estável)");
System.out.println("KnowledgeStore (Port)   1   0   0.00 (estável)");
System.out.println("ToolRegistry (Port)     1   0   0.00 (estável)");
System.out.println("AgentServiceImpl        0   3   1.00 (instável) ← esperado!");
System.out.println("SimulatedLLMGateway     1   0   0.00");
System.out.println("Main (composição)       0   5   1.00 (instável) ← esperado!");
System.out.println();

// DIP compliance
System.out.println("═══════ DIP COMPLIANCE ═══════");
System.out.println("AgentServiceImpl depende de:");
System.out.println("  ✅ LLMGateway (interface)");
System.out.println("  ✅ KnowledgeStore (interface)");
System.out.println("  ✅ ToolRegistry (interface)");
System.out.println("  ❌ Nenhuma classe concreta!");
System.out.println("  → DIP: 100% compliant ✅");
System.out.println();

// Coesão
System.out.println("═══════ COESÃO ═══════");
System.out.println("AgentServiceImpl: 5 métodos, todos usam ≥2 campos");
System.out.println("  → LCOM (Lack of Cohesion): BAIXO → Alta coesão ✅");
System.out.println();

System.out.println("═══════ COMPLEXIDADE ═══════");
System.out.println("processGoal(): Complexidade ciclomática = 1 (sem branches)");
System.out.println("  → Simples e linear: Goal → RAG → Plan → Reflect → Tools ✅");

// %% [markdown]
// ## 🔹 Passo 3 — Decision Model do Artigo CSIRO

// %%
// ══ DECISION MODEL — Seção 5.1 do artigo CSIRO ══

System.out.println("╔══════════════════════════════════════════════════════════╗");
System.out.println("║      DECISION MODEL — Seleção de Padrões CSIRO          ║");
System.out.println("╠══════════════════════════════════════════════════════════╣");
System.out.println("║                                                          ║");
System.out.println("║  O usuário interage via texto ou multimodal?             ║");
System.out.println("║  ├── Texto → Passive Goal Creator                        ║");
System.out.println("║  └── Multimodal → Proactive Goal Creator                ║");
System.out.println("║                                                          ║");
System.out.println("║  O agente precisa de conhecimento externo?               ║");
System.out.println("║  ├── Sim → RAG                                           ║");
System.out.println("║  └── Não → One-Shot/Incremental Querying                ║");
System.out.println("║                                                          ║");
System.out.println("║  O plano deve ter alternativas?                          ║");
System.out.println("║  ├── Sim → Multi-Path Plan Generator                     ║");
System.out.println("║  └── Não → Single-Path Plan Generator                   ║");
System.out.println("║                                                          ║");
System.out.println("║  Quem revisa o plano?                                    ║");
System.out.println("║  ├── O próprio agente → Self-Reflection                  ║");
System.out.println("║  ├── Outro agente → Cross-Reflection                     ║");
System.out.println("║  └── Humano → Human Reflection                          ║");
System.out.println("║                                                          ║");
System.out.println("║  Múltiplos agentes cooperam?                             ║");
System.out.println("║  ├── Sim, democraticamente → Voting-based               ║");
System.out.println("║  ├── Sim, com papéis → Role-based                       ║");
System.out.println("║  └── Sim, argumentando → Debate-based                   ║");
System.out.println("║                                                          ║");
System.out.println("║  Precisa de guardrails de segurança?                     ║");
System.out.println("║  └── Sim → Multimodal Guardrails                        ║");
System.out.println("╚══════════════════════════════════════════════════════════╝");

System.out.println("\n📝 TAREFA: Aplique o Decision Model ao agente da Fase 4.");
System.out.println("   Para cada pergunta, indique qual padrão foi escolhido");
System.out.println("   e quais trade-offs essa escolha implica.");

// %% [markdown]
// ## 🔹 Passo 4 — Exercício de Refactoring
//
// Analise o código da Fase 4 e proponha **3 refatorações** usando padrões adicionais do catálogo CSIRO. Para cada refatoração:
// 1. Identifique o problema atual (code smell ou limitação)
// 2. Indique qual padrão CSIRO/GoF resolve
// 3. Esboce a solução (código ou diagrama)

// %%
// ══ SUGESTÕES DE REFACTORING ══

System.out.println("🔧 REFACTORING SUGERIDO #1:");
System.out.println("   Problema: processGoal() é linear — não há proteção contra");
System.out.println("   inputs maliciosos ou outputs indesejados do LLM.");
System.out.println("   Padrão: Multimodal Guardrails (CSIRO) + Proxy (GoF)");
System.out.println("   Solução: criar GuardrailProxy que envolve o LLMGateway,");
System.out.println("   filtrando inputs/outputs antes de chegar ao domínio.");
System.out.println();

System.out.println("🔧 REFACTORING SUGERIDO #2:");
System.out.println("   Problema: apenas Self-Reflection — não há feedback externo.");
System.out.println("   Padrão: Cross-Reflection (CSIRO) + Observer (GoF)");
System.out.println("   Solução: registrar múltiplos 'Reflectors' que são notificados");
System.out.println("   quando um plano é gerado, cada um adicionando sua perspectiva.");
System.out.println();

System.out.println("🔧 REFACTORING SUGERIDO #3:");
System.out.println("   Problema: plano gerado é single-path — sem alternativas.");
System.out.println("   Padrão: Multi-Path Plan Generator (CSIRO) + Strategy (GoF)");
System.out.println("   Solução: gerar 3 planos com temperaturas diferentes e");
System.out.println("   permitir que o usuário escolha (Human Reflection).");
System.out.println();

System.out.println("📝 TAREFA DO GRUPO:");
System.out.println("   Implemente pelo menos 1 das refatorações acima.");
System.out.println("   Documente o antes/depois com diagrama de classes.");

// %% [markdown]
// ## 📝 Avaliação — Fase 5
//
// **Q1.** Qual atributo ISO 25010 o padrão Multimodal Guardrails mais impacta?
// ( ) Funcionalidade  ( ) Eficiência  (X) Segurança  ( ) Portabilidade
//
// **Q2.** A métrica de Instabilidade (Ce/(Ca+Ce)) igual a 0.00 indica:
// ( ) Uma classe sem funcionalidade
// (X) Uma classe totalmente estável (muitos dependem dela, ela não depende de ninguém)
// ( ) Uma classe com muitos bugs
// ( ) Uma classe que deve ser refatorada urgentemente
//
// **Q3.** No Decision Model CSIRO, se o agente precisa de conhecimento atualizado externo, qual padrão é indicado?
// ( ) Self-Reflection  (X) RAG  ( ) Multimodal Guardrails  ( ) Voting-based Cooperation
//
// **Q4.** O que é Complexidade Ciclomática?
// ( ) O número de linhas de código em uma classe
// (X) O número de caminhos linearmente independentes pelo código
// ( ) A quantidade de dependências de uma classe
// ( ) O tempo de compilação do módulo
//
// **Q5.** O DIP (Dependency Inversion Principle) foi atingido no agente da Fase 4 porque:
// ( ) Todas as classes são abstratas
// (X) O domain service depende apenas de interfaces (Ports), não de implementações concretas
// ( ) O Main.java não importa nenhuma classe
// ( ) Os testes não usam mocks
//
// **Q6.** Se quisermos adicionar Cross-Reflection ao agente, qual padrão GoF nos ajuda a notificar múltiplos reflectors?
// ( ) Factory Method  (X) Observer  ( ) Singleton  ( ) Builder
//
// **Q7.** LCOM (Lack of Cohesion of Methods) baixo indica:
// ( ) Uma classe com muitas responsabilidades
// (X) Uma classe altamente coesa — seus métodos acessam os mesmos campos
// ( ) Uma classe sem métodos públicos
// ( ) Uma classe com muitos construtores
//
// **Q8.** No artigo CSIRO, a seção "Consequences" de cada padrão apresenta:
// ( ) Apenas os benefícios do padrão
// ( ) Apenas os riscos do padrão
// (X) Trade-offs: benefícios E impactos negativos nas qualidades do software
// ( ) Uma lista de linguagens compatíveis
//
// **Q9.** O Guardrail Proxy (refactoring sugerido) é um exemplo de composição de:
// (X) Multimodal Guardrails (CSIRO) + Proxy (GoF)
// ( ) RAG (CSIRO) + Adapter (GoF)
// ( ) Self-Reflection (CSIRO) + Singleton (GoF)
// ( ) Agent Evaluator (CSIRO) + Iterator (GoF)
//
// **Q10.** O Agent Evaluator do CSIRO é usado para:
// ( ) Treinar novos modelos de IA
// (X) Testar e avaliar o agente em relação a requisitos e métricas
// ( ) Substituir agentes com baixo desempenho
// ( ) Compilar o código Java do agente
